# %% [markdown]
# # Module 1: Demystifying ​Quantum Computing

# %% [markdown]
# ## Mount google drive and install dependencies

# %% [markdown]
# Mount your google drive (might take few seconds for dialog to appear).

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/Shareddrives
import os
folder = os.path.join(os.popen('pwd | tr -d \'\n\'').read(),os.popen('ls | grep QPCC_1_ | tr -d \'\n\'').read())
os.chdir(folder)
os.getcwd()
# Out:
# Mounted at /content/drive
# /content/drive/Shareddrives
# '/content/drive/Shareddrives/QPCC_1_Daniel_Lete'

# %% [markdown]
# Install the required python packages.

# %%
# !pip install --quiet -r 'Material/requirements.txt'
from qpcc import *
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.4/993.4 KB 16.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 60.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 62.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.3/241.3 KB 19.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 KB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 KB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 59.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.5/37.5 MB 14.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 67.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Lecture

# %% [markdown]
# The lecture video is accessible directly in the notebook below or in Youtube - link to full video and chapter available below.

# %%
lecture = 'Lec001'
qpcc_player(video_id=lecture)

# %% [markdown]
# ### Direct Youtube link
#
# [Full lecture](https://www.youtube.com/watch?v=S5x1N9vLM7g&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd)
#
#
# ### Chapters
#
# [00:00:00](https://www.youtube.com/watch?v=S5x1N9vLM7g&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd&index=2&t=0s) - Outline
#
# [00:01:38](https://www.youtube.com/watch?v=S5x1N9vLM7g&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd&index=2&t=98s) - The era of high-performance computing
#
# [00:18:41](https://www.youtube.com/watch?v=S5x1N9vLM7g&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd&index=2&t=1121s) - Where does quantum computing fit?
#
# [00:45:32](https://www.youtube.com/watch?v=S5x1N9vLM7g&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd&index=2&t=2732s) - How does the quantum computing ecosystem look?
#
# [01:01:58](https://www.youtube.com/watch?v=S5x1N9vLM7g&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd&index=2&t=3718s) - What does QPCC offer you?
#
# [01:10:37](https://www.youtube.com/watch?v=S5x1N9vLM7g&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd&index=2&t=4237s) - Wrap-up

# %% [markdown]
# # Tutorial
# ##### For each question in the quiz, select all choices that you think are correct.

# %%
qpcc_quiz(lecture)

# %% [markdown]
# There are a number of cards below that could be used to check your undertstanding ot the topics presented in the lecture and they could also be used as discission points in the tutorial. Clicking on a card would reveal an answer.

# %%
qpcc_cards(lecture)

# %% [markdown]
# # Exercises

# %% [markdown]
# The exercise for this lecture will be to prepare a *QPCC Self-Study Report* for your own use or your organiastion. Place this report under a file name *QPCC_SelfStudy_Report.doc* in your QPCC shared drive.
#
# The purpose of the report is to document your understanding and roadmap for engaging with quantum computing by addressing the following 5 (five) items from this lecture:
#
#  1. Describe where classical HPC is relevant/important for you using a problem/use-case​.
#  2. Describe your understanding of how quantum computing is different to classical HPC​.
#  3. Briefly describe where, how or any quantum computing is likely to be relevant to your problem/use-case​.
#  4. Summarise which key stakeholders and players you will target​.
#  5. Define what is your overall objective in studying quantum computing through QPCC (understand technology, landscape, players, tools, algorithms, applications, collaboration, investments, etc.).
#
# Your *QPCC Self-Study Report* report will be further refined in the subsequent lecture exercises by incrementally adding more details and ideas.
#
# At the end of your attendace of the Quantum Programming Certification Course, the final version of this report will serve to demonstrate your learning outcomes and achievements feeding into your roadmap to continue engagement with quantum computing.

# %% [markdown]
# # References

# %% [markdown]
# The following references are optional reading material:
# 1.   Quantum technology: the next revolution. https://www.thalesgroup.com/en/quantum-technology-next-revolution
# 2.   [European Quantum Flagship Strategic Research & Industry Agenda](https://qt.eu/about-quantum-flagship/newsroom/quantum-flagship-publishes-preliminary-strategic-research-and-industry-agenda/) (SRIA), https://qt.eu//app/uploads/2022/11/Quantum-Flagship_SRIA_2022.pdf
# 3. in Quantum Computing: Progress and prospects, https://nap.nationalacademies.org/catalog/25196/quantum-computing-progress-and-prospects
