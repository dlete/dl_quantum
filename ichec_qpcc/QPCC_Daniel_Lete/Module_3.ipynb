# %% [markdown]
# ## Mount google drive and install dependencies

# %% [markdown]
# Mount your google drive (might take few seconds for dialog to appear).

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/Shareddrives
import os
folder = os.path.join(os.popen('pwd | tr -d \'\n\'').read(),os.popen('ls | grep QPCC_1_ | tr -d \'\n\'').read())
os.chdir(folder)
os.getcwd()
#%cd QPCC
# Out:
# Mounted at /content/drive
# /content/drive/Shareddrives
# '/content/drive/Shareddrives/QPCC_1_Daniel_Lete'

# %% [markdown]
# Install the required python packages.

# %%
# !pip install --quiet -r 'Material/requirements.txt'
from qpcc import *
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.4/993.4 KB 17.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 91.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 105.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.3/241.3 KB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 KB 14.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 72.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 15.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Module 3: From Bits to Qubits

# %% [markdown]
# # Lecture

# %% [markdown]
# The lecture video is accessible directly in the notebook below or in Youtube - link to full video and chapter available below.

# %%
lecture = 'Lec003'
qpcc_player(video_id=lecture)

# %% [markdown]
# ### Direct Youtube link
#
# [Full lecture](https://youtu.be/o5IeqQi9n3s)
#
#
# ### Chapters
# [0:17](https://www.youtube.com/watch?v=o5IeqQi9n3s&t=17s) Introduction
#
# [02:01](https://www.youtube.com/watch?v=o5IeqQi9n3s&t=121s) Bits
#
# [06:41](https://www.youtube.com/watch?v=o5IeqQi9n3s&t=401s) Encoding Numbers with Bits
#
# [11:24](https://www.youtube.com/watch?v=o5IeqQi9n3s&t=684s) Implementing Adding with Gates
#
# [15:54](https://www.youtube.com/watch?v=o5IeqQi9n3s&t=954s) Features of Classical Computing
#
# [18:18](https://www.youtube.com/watch?v=o5IeqQi9n3s&t=1098s) Qubits
#
# [23:43](https://www.youtube.com/watch?v=o5IeqQi9n3s&t=1423s) Quantum Measurement
#
# [28:33](https://www.youtube.com/watch?v=o5IeqQi9n3s&t=1713s) Quantum Gates
#
# [34:38](https://www.youtube.com/watch?v=o5IeqQi9n3s&t=2078s) Features of Quantum Computing

# %% [markdown]
# # Tutorial
# ##### For each question in the quiz, select all choices that you think are correct

# %%
qpcc_quiz(lecture)
# Out:
# <div id="nQoadllrknLC" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-numquestions="1000000"> <style>:root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Answer {
#     margin: 10px 0;
#     display: grid;
#     grid-template-columns: auto auto;
#     grid-gap: 10px;
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
# ...

# %% [markdown]
# There are a number of cards below that could be used to check your undertstanding ot the topics presented in the lecture and they could also be used as discission points in the tutorial. Clicking on a card would reveal an answer.

# %%
qpcc_cards(lecture)
# Out:
# <style>
# :root{
#   --asparagus: #87a878ff;
#   --terra-cotta: #e26d5aff;
#   --cyan-process: #5bc0ebff;
#   --dark-blue-gray: #666a86ff;
#   --snow: #fffafbff;
#   --rich-black-fogra-39: #090c08ff;
# }
#
#
# /* entire container, keeps perspective */
# .flip-container {
# 	perspective: 1000px;
#   touch-action: pinch-zoom pan-y;
# }
#
#
# .flip-container.flip .flipper {
# 	transform: rotateY(180deg);
# 	/*transform: rotateY(180deg)  translateX(-10%); */
# }
#
#
# .flip-container.slide .flipper.frontcard {
#     filter: brightness(90%);
#     position:absolute;
#     z-index: -20;
# }
#
# .flip-container.prepare .flipper.backcard {
#     opacity:1;
#     transition: display 0s;
#     transform:  translateX(20px);
# }
#
#
# .flip-container.slide .flipper.backcard {
#     filter: brightness(115%);
#     height: 360px;
#     opacity:1;
# 	  transform:  rotateY(3deg)  translateX(700px) translateZ(20px) scale(1, 1.05) rotate(3deg);
#     z-index: 20;
# }
#
#
#
#
# ...

# %% [markdown]
# # Exercises

# %% [markdown]
# In this Module we will use the [IBM Quantum Composer](https://quantum-computing.ibm.com/composer/files/new?needs_refill=true) online to experimentally demonstrate some of the concepts we covered in the lecture and the tutorial
#
# 1. Implement the X gate on state |0⟩ and show that measuring it gives the |1⟩state with 100% probability
#
# 2. Perform the CNOT gate on the state input |00⟩ and |10⟩ to show that it copies the state from the Control qubit to the target qubit.
#
# 3. In the tutorial we discussed the existence of 4 Bellstates, can you construct circuits for the other 3 bell statesand look at how the measurement results of the 2 qubits are correlated.

# %% [markdown]
# # References

# %% [markdown]
# The following references are optional reading material:
# 1.   The following chapters of the textbook Introduction to Classical and Quantum Computing([pdf](https://www.thomaswong.net/introduction-to-classical-and-quantum-computing-1e3p.pdf))
# : 1.1, 1.2, 1.3, 2.2, 2.3, 2.6, 4.4
#
# 2.   [Qiskit Textbook for S gate and T gate](https://qiskit.org/textbook/ch-states/single-qubit-gates.html#6.-The-I,-S-and-T-gates--)
