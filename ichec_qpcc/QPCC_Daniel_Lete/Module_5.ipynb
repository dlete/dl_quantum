# %% [markdown]
# # Module 5: Accessing Quantum Computing Systems

# %% [markdown]
# ## Mount google drive and install dependencies

# %% [markdown]
# Mount your google drive (might take few seconds for dialog to appear).

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/Shareddrives
import os
folder = os.path.join(os.popen('pwd | tr -d \'\n\'').read(),os.popen('ls | grep QPCC_1_ | tr -d \'\n\'').read())
os.chdir(folder)
os.getcwd()
#%cd QPCC
# Out:
# Mounted at /content/drive
# /content/drive/Shareddrives
# '/content/drive/Shareddrives/QPCC_1_Daniel_Lete'

# %% [markdown]
# Install the required python packages.

# %%
# !pip install --quiet -r 'Material/requirements.txt'
from qpcc import *

# %% [markdown]
# # Lecture

# %% [markdown]
# The lecture video is accessible directly in the notebook below or in Youtube - link to full video and chapter available below.

# %%
lecture = 'Lec005'
qpcc_player(video_id=lecture)

# %% [markdown]
# ### Direct Youtube link
#
# [Full lecture](https://www.youtube.com/watch?v=7r1yrueMgZs)
#
#
# ### Chapters
# [00:00](https://www.youtube.com/watch?v=7r1yrueMgZs&t=0s) Intro
#
# [01:50](https://www.youtube.com/watch?v=7r1yrueMgZs&t=110s) Executing Quantum Programs
#
# [10:46](https://www.youtube.com/watch?v=7r1yrueMgZs&t=646s) Local Quantum Systems
#
# [14:27](https://www.youtube.com/watch?v=7r1yrueMgZs&t=867s) Tightly-Integrated Quantum Systems
#
# [18:57](https://www.youtube.com/watch?v=7r1yrueMgZs&t=1137s) Heterogenous Quantum Systems
#
# [22:12](https://www.youtube.com/watch?v=7r1yrueMgZs&t=1332s) Publicly Funded Quantum Systems

# %% [markdown]
# # Tutorial
# ##### For each question in the quiz, select all choices that you think are correct

# %%
qpcc_quiz(lecture)
# Out:
# <div id="gdZwUJhIoBbR" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-numquestions="1000000"> <style>:root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Answer {
#     margin: 10px 0;
#     display: grid;
#     grid-template-columns: auto auto;
#     grid-gap: 10px;
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
# ...

# %% [markdown]
# There are a number of cards below that could be used to check your undertstanding ot the topics presented in the lecture and they could also be used as discission points in the tutorial. Clicking on a card would reveal an answer.

# %%
qpcc_cards(lecture)
# Out:
# <style>
# :root{
#   --asparagus: #87a878ff;
#   --terra-cotta: #e26d5aff;
#   --cyan-process: #5bc0ebff;
#   --dark-blue-gray: #666a86ff;
#   --snow: #fffafbff;
#   --rich-black-fogra-39: #090c08ff;
# }
#
#
# /* entire container, keeps perspective */
# .flip-container {
# 	perspective: 1000px;
#   touch-action: pinch-zoom pan-y;
# }
#
#
# .flip-container.flip .flipper {
# 	transform: rotateY(180deg);
# 	/*transform: rotateY(180deg)  translateX(-10%); */
# }
#
#
# .flip-container.slide .flipper.frontcard {
#     filter: brightness(90%);
#     position:absolute;
#     z-index: -20;
# }
#
# .flip-container.prepare .flipper.backcard {
#     opacity:1;
#     transition: display 0s;
#     transform:  translateX(20px);
# }
#
#
# .flip-container.slide .flipper.backcard {
#     filter: brightness(115%);
#     height: 360px;
#     opacity:1;
# 	  transform:  rotateY(3deg)  translateX(700px) translateZ(20px) scale(1, 1.05) rotate(3deg);
#     z-index: 20;
# }
#
#
#
#
# ...

# %% [markdown]
# # Exercises

# %% [markdown]
# 1. Extend your report to compare quantum computing stacks:
#   - Tightly-integrated vs heterogenous quantum system
#   - Publicly-funded vs commercial quantum system
#
# 2. In this module we will use IBM Qiskit to repeat in code some of the exercises done on the IBM quantum composer in the previous module. The exercises can be found in the notebook Module_5_exercises.ipynb in your drive. They are as follows:
#
#   2.1 Code the circuits for the Bell states, draw the circuits, run the circuits for 1024 shots using the statevector simulator and plot the results on a graph.
#
#   2.2 Use one of the Bell states above and compare the results obtained when using the matrix product state (tensor-network) simulator.
#
#   2.3 Qubit Entanglement - Code the 3-qubit maximally entangled state called the GHZ state, and repeat the comparison above between the statevector simulator and the matrix-product state(tensor-network) simulator.
#
#   2.4 Optional Advanced Question : Running circuits on the Noisy simulators provided by IBM giving acess to the noise models from the devices locally
#     1. Submit the circuits constructed on the first three exercises to a Noisy Backend simulator
#     2. Observe the results and compare the effect of noise on the histogram plot.

# %% [markdown]
# # References

# %% [markdown]
# The following references are optional reading material:
# 1.  IBM quantum software simulators types [link](https://quantum-computing.ibm.com/lab/docs/iql/manage/simulator)
# 2. IBM quantum software simulators tutorial [link](https://qiskit.org/documentation/tutorials/simulators/1_aer_provider.html)
# 2. IBM Qiskit [single qubit gates](https://qiskit.org/textbook/ch-states/single-qubit-gates.html) and [multi qubit gates](https://qiskit.org/textbook/ch-gates/multiple-qubits-entangled-states.html)
# 4. Introduction to Classical and Quantum Computing([pdf](https://www.thomaswong.net/introduction-to-classical-and-quantum-computing-1e3p.pdf))
#
#   Chapters :
#
#   5.3.2, 5.3.3, 5.3.4 - Quantum Lab, Quantum Processor and Simulator using Qiskit programming language
#
#   6.2.1 - EPR paradox
#
#   6.2.2 - Bell test (first paragraph)
#
#   6.1.2, 6.1.3 - Maximally and Partially Entagled States
#
#   6.2.5 - No-Signaling principle
#
#   6.2.6 - Other theoretical explanation of entanglement
