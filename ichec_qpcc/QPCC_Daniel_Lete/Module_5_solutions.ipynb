# %% [markdown]
# # QPCC Module 5 Solutions

# %%
# Imports

# Imports
try:
  from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, Aer, execute
  from qiskit.tools.monitor import job_monitor
  from qiskit.visualization import plot_histogram
  from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, Aer, execute
  from qiskit.tools.monitor import job_monitor
  from qiskit.visualization import plot_histogram
except ImportError as e:
  print('Qiskit not installed, installing now ...')
  # !pip install qiskit
  from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, Aer, execute
  from qiskit.tools.monitor import job_monitor
  from qiskit.visualization import plot_histogram
  from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, Aer, execute
  from qiskit.tools.monitor import job_monitor
  from qiskit.visualization import plot_histogram
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 33.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 71.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.5/241.5 kB 18.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.5/129.5 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.5/37.5 MB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 50.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.7/112.7 kB 9.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Example:
#
# Create a circuit for the first Bell state, draw the circuit, run the circuit for 1024 shots using the staevector simulator and plot the result on a graph.

# %% [markdown]
# ### Create a circuit

# %%
# Create a quantum register with two qubits
qreg_q = QuantumRegister(2, 'q')
# Create a register to store two classical values
creg_c = ClassicalRegister(2, 'c')
# Define a quantum circuit, using the two registers avove
circuit = QuantumCircuit(qreg_q, creg_c)

# Apply a Hadamard gate to the first qubit (index 0)
circuit.h(qreg_q[0])
# Apply a CNOT gate between the first qubit (control qubit) and the second qubit (target qubit)
circuit.cx(qreg_q[0], qreg_q[1])
# Measure the first qubit and store the result in the first classical register 
circuit.measure(qreg_q[0], creg_c[0])
# Measure the second qubit and store the result in the second classical register 
circuit.measure(qreg_q[1], creg_c[1])

# %% [markdown]
# ### Draw the circuit

# %%
circuit.draw()
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  1

# %% [markdown]
# ### Define the *statevector* simulator as the execution backend

# %%
# simulator = Aer.get_backend('aer_simulator_matrix_product_state')
simulator = Aer.get_backend('aer_simulator_statevector')

# %% [markdown]
# ### Run the Bell circuit on the statevector simulator and repeat 1024 times

# %%
job = execute(circuit, simulator, shots=1024)
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %% [markdown]
# ### Get the resulting measurements

# %%
counts = job.result().get_counts()

print(counts)
# Out:
# {'11': 511, '00': 513}

# %% [markdown]
# ### Plot the resulting measurement

# %%
plot_histogram(counts)

# %% [markdown]
# ## Exercise 2.1
#
# Code the circuits for the remaining three Bell states, draw the circuits, run the circuits for 1024 shots using the statevector simulator and plot the results on a graph.

# %% [markdown]
# ### Create a circuit (Bell State 2)

# %%
# Create a quantum register with two qubits
qreg_q = QuantumRegister(2, 'q')
# Create a register to store two classical values
creg_c = ClassicalRegister(2, 'c')
# Define a quantum circuit, using the two registers avove
bellstate2 = QuantumCircuit(qreg_q, creg_c)

# Apply an X gate to the first qubit (index 0)
bellstate2.x(qreg_q[0])
# Apply a Hadamard gate to the first qubit (index 0)
bellstate2.h(qreg_q[0])
# Apply a CNOT gate between the first qubit (control qubit) and the second qubit (target qubit)
bellstate2.cx(qreg_q[0], qreg_q[1])
# Measure the first qubit and store the result in the first classical register 
bellstate2.measure(qreg_q[0], creg_c[0])
# Measure the second qubit and store the result in the second classical register 
bellstate2.measure(qreg_q[1], creg_c[1])

# %% [markdown]
# ### Draw the circuit

# %%
bellstate2.draw()
# Out:
#      ┌───┐┌───┐     ┌─┐
# q_0: ┤ X ├┤ H ├──■──┤M├───
#      └───┘└───┘┌─┴─┐└╥┘┌─┐
# q_1: ──────────┤ X ├─╫─┤M├
#                └───┘ ║ └╥┘
# c: 2/════════════════╩══╩═
#                      0  1

# %% [markdown]
# ### Define the *statevector* simulator as the execution backend

# %%
simulator = Aer.get_backend('aer_simulator_statevector')

# %% [markdown]
# ### Run the Bell circuit on the statevector simulator and repeat 1024 times

# %%
job = execute(bellstate2, simulator, shots=1024)
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %% [markdown]
# ### Get the resulting measurements

# %%
counts = job.result().get_counts()

print(counts)
# Out:
# {'11': 493, '00': 531}

# %% [markdown]
# ### Plot the resulting measurement

# %%
plot_histogram(counts)

# %% [markdown]
# ### Create a circuit (Bell State 3)

# %%
# Create a quantum register with two qubits
qreg_q = QuantumRegister(2, 'q')
# Create a register to store two classical values
creg_c = ClassicalRegister(2, 'c')
# Define a quantum circuit, using the two registers avove
bellstate3 = QuantumCircuit(qreg_q, creg_c)

# Apply an X gate to the first qubit (index 0)
bellstate3.x(qreg_q[0])
# Apply an X gate to the second qubit (index 1)
bellstate3.x(qreg_q[1])


# Apply a Hadamard gate to the first qubit (index 0)
bellstate3.h(qreg_q[0])
# Apply a CNOT gate between the first qubit (control qubit) and the second qubit (target qubit)
bellstate3.cx(qreg_q[0], qreg_q[1])
# Measure the first qubit and store the result in the first classical register 
bellstate3.measure(qreg_q[0], creg_c[0])
# Measure the second qubit and store the result in the second classical register 
bellstate3.measure(qreg_q[1], creg_c[1])

# %% [markdown]
# ### Draw the circuit

# %%
bellstate3.draw()
# Out:
#      ┌───┐┌───┐     ┌─┐
# q_0: ┤ X ├┤ H ├──■──┤M├───
#      ├───┤└───┘┌─┴─┐└╥┘┌─┐
# q_1: ┤ X ├─────┤ X ├─╫─┤M├
#      └───┘     └───┘ ║ └╥┘
# c: 2/════════════════╩══╩═
#                      0  1

# %% [markdown]
# ### Define the *statevector* simulator as the execution backend

# %%
simulator = Aer.get_backend('aer_simulator_statevector')

# %% [markdown]
# ### Run the Bell circuit on the statevector simulator and repeat 1024 times

# %%
job = execute(bellstate3, simulator, shots=1024)
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %% [markdown]
# ### Get the resulting measurements

# %%
counts = job.result().get_counts()

print(counts)
# Out:
# {'01': 513, '10': 511}

# %% [markdown]
# ### Plot the resulting measurement

# %%
plot_histogram(counts)

# %% [markdown]
# ### Create a circuit (Bell State 4)

# %%
# Create a quantum register with two qubits
qreg_q = QuantumRegister(2, 'q')
# Create a register to store two classical values
creg_c = ClassicalRegister(2, 'c')
# Define a quantum circuit, using the two registers avove
bellstate4 = QuantumCircuit(qreg_q, creg_c)

# Apply an X gate to the second qubit (index 1)
bellstate4.x(qreg_q[1])


# Apply a Hadamard gate to the first qubit (index 0)
bellstate4.h(qreg_q[0])
# Apply a CNOT gate between the first qubit (control qubit) and the second qubit (target qubit)
bellstate4.cx(qreg_q[0], qreg_q[1])
# Measure the first qubit and store the result in the first classical register 
bellstate4.measure(qreg_q[0], creg_c[0])
# Measure the second qubit and store the result in the second classical register 
bellstate4.measure(qreg_q[1], creg_c[1])

# %% [markdown]
# ### Draw the circuit

# %%
bellstate4.draw()
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      ├───┤┌─┴─┐└╥┘┌─┐
# q_1: ┤ X ├┤ X ├─╫─┤M├
#      └───┘└───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  1

# %% [markdown]
# ### Define the *statevector* simulator as the execution backend

# %%
simulator = Aer.get_backend('aer_simulator_statevector')

# %% [markdown]
# ### Run the Bell circuit on the statevector simulator and repeat 1024 times

# %%
job = execute(bellstate4, simulator, shots=1024)
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %% [markdown]
# ### Get the resulting measurements

# %%
counts = job.result().get_counts()

print(counts)
# Out:
# {'10': 511, '01': 513}

# %% [markdown]
# ### Plot the resulting measurement

# %%
plot_histogram(counts)

# %% [markdown]
# ## Exercise 2.2
#
# Use one of the Bell states above and compare the results obtained when using the matrix product state (tensor-network) simulator

# %% [markdown]
# ### Create a circuit

# %%
# Create a quantum register with two qubits
qreg_q = QuantumRegister(2, 'q')
# Create a register to store two classical values
creg_c = ClassicalRegister(2, 'c')
# Define a quantum circuit, using the two registers avove
bellstate4 = QuantumCircuit(qreg_q, creg_c)

# Apply an X gate to the second qubit (index 1)
bellstate4.x(qreg_q[1])


# Apply a Hadamard gate to the first qubit (index 0)
bellstate4.h(qreg_q[0])
# Apply a CNOT gate between the first qubit (control qubit) and the second qubit (target qubit)
bellstate4.cx(qreg_q[0], qreg_q[1])
# Measure the first qubit and store the result in the first classical register 
bellstate4.measure(qreg_q[0], creg_c[0])
# Measure the second qubit and store the result in the second classical register 
bellstate4.measure(qreg_q[1], creg_c[1])

# %% [markdown]
# ### Define the *matrix product state* simulator as the execution backend

# %%
simulator = Aer.get_backend('aer_simulator_matrix_product_state')

# %% [markdown]
# ### Run the Bell circuit on the matrix product state simulator and repeat 1024 times

# %%
job = execute(bellstate4, simulator, shots=1024)
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %% [markdown]
# ### Get and plot the resulting measurements

# %%
counts = job.result().get_counts()

print(counts)
# Out:
# {'10': 507, '01': 517}

# %%
plot_histogram(counts)

# %% [markdown]
# ## Exercise 2.3
#
# Qubit Entanglement - Code the 3-qubit maximally entangled state called the GHZ state, and repeat the comparison above between the statevector simulator and the matrix-product state(tensor-network) simulator.

# %% [markdown]
# ### Create the GHZ circuit

# %%
qreg_q = QuantumRegister(3, 'q')
creg_c = ClassicalRegister(3, 'c')
GHZ = QuantumCircuit(qreg_q, creg_c)
#Apply Hadamard gate on first qubit (q[0])
GHZ.h(qreg_q[0])
#Apply ControlX gate between first and second qubit (q[0],q[1])
GHZ.cx(qreg_q[0], qreg_q[1])
#Apply ControlX gate between first and third qubit (q[0],q[2])
GHZ.cx(qreg_q[0], qreg_q[2])
#Measure all three qubits
GHZ.measure(qreg_q[1], creg_c[0])
GHZ.measure(qreg_q[0], creg_c[1])
GHZ.measure(qreg_q[2], creg_c[2])

# %%
GHZ.draw()
# Out:
#      ┌───┐             ┌─┐
# q_0: ┤ H ├──■────■─────┤M├───
#      └───┘┌─┴─┐  │  ┌─┐└╥┘
# q_1: ─────┤ X ├──┼──┤M├─╫────
#           └───┘┌─┴─┐└╥┘ ║ ┌─┐
# q_2: ──────────┤ X ├─╫──╫─┤M├
#                └───┘ ║  ║ └╥┘
# c: 3/════════════════╩══╩══╩═
#                      1  0  2

# %% [markdown]
# ### Define the desired simulator type as the execution backend

# %%
simulator = Aer.get_backend('aer_simulator_statevector')

# %% [markdown]
# ### Run the GHZ circuit on the desired simulator and repeat 1024 times

# %%
job = execute(GHZ,simulator,shots = 1024)
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %% [markdown]
# ### Get and plot the resulting measurements

# %%
counts = job.result().get_counts()

print(counts)
# Out:
# {'000': 525, '111': 499}

# %%
plot_histogram(counts)

# %% [markdown]
# ## Exercise 2.4
#
# Optional Advanced Question : Running circuits on the Noisy simulators provided by IBM giving acess to the noise models from the devices locally.
#
#
#   1. Submit the circuits constructed on the first three exercises to a Noisy Backend simulator
#   2. Observe the results and compare the effect of noise on the histogram plot.

# %% [markdown]
# ### Import the required backend with the noise model:
#
# From the link below you can get acess to multiple of the fake backends provided by IBM you can import any or all of these backend and prerpare a backend on which any job can be executed. In this example we are using **FakeQuito**
#
# https://qiskit.org/documentation/apidoc/providers_fake_provider.html

# %%
from qiskit.providers.fake_provider import FakeQuito

device_backend = FakeQuito()

# %% [markdown]
# ### Run the circuit of choice on the above created backend

# %%
#Prepare a bell state circuit 
noisyqreg_q = QuantumRegister(2, 'q')
noisycreg_c = ClassicalRegister(2, 'c')
noisycirq = QuantumCircuit(noisyqreg_q, noisycreg_c)
noisycirq.h(noisyqreg_q[0])
noisycirq.cx(noisyqreg_q[0], noisyqreg_q[1])
noisycirq.measure(noisyqreg_q[0], noisycreg_c[0])
noisycirq.measure(noisyqreg_q[1], noisycreg_c[1])


# Run the job on the device_backend imported above
job = execute(noisycirq, device_backend, shots=1024)
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %%
noisycirq.draw()
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  1

# %% [markdown]
# ### Plotting measurement outcomes

# %%
hist = job.result().get_counts()

print(hist)
# Out:
# {'01': 26, '10': 38, '00': 508, '11': 452}

# %%
plot_histogram(hist)

# %% [markdown]
# ### Repeat the process above for all the different circuits defined in the previous sections

# %% [markdown]
# **Noisy Bellstate 2**

# %%
job = execute(bellstate2,device_backend,shots = 1024)
job_monitor(job)
counts = job.result().get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Job Status: job has successfully run
# {'01': 41, '10': 50, '00': 506, '11': 427}

# %% [markdown]
# **Noisy Bellstate 3**

# %%
job = execute(bellstate3,device_backend,shots = 1024)
job_monitor(job)
counts = job.result().get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Job Status: job has successfully run
# {'11': 20, '01': 466, '00': 59, '10': 479}

# %% [markdown]
# **Noisy Bellstate 4**

# %%
job = execute(bellstate4,device_backend,shots = 1024)
job_monitor(job)
counts = job.result().get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Job Status: job has successfully run
# {'11': 11, '10': 474, '00': 68, '01': 471}

# %% [markdown]
# **Noisy GHZ**

# %%
job = execute(GHZ,device_backend,shots = 1024)
job_monitor(job)
counts = job.result().get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Job Status: job has successfully run
# {'001': 11, '110': 12, '000': 478, '010': 22, '011': 28, '111': 353, '100': 18, '101': 102}

# %% [markdown]
# ###Using different noisy backend

# %%
from qiskit.providers.fake_provider import FakeManila

device_backend = FakeManila()

# %% [markdown]
# ###Running noisy bellstate on Manila Backend and plotting results

# %%
job = execute(noisycirq,device_backend,shots = 1024)
job_monitor(job)
counts = job.result().get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Job Status: job has successfully run
# {'01': 42, '11': 374, '10': 122, '00': 486}

# %% [markdown]
# Compare the results obtained by using Quito Backend Vs. using Manila backend.
