# %% [markdown]
# # Module 4: Realizing Quantum Computing Systems

# %% [markdown]
# ## Mount google drive and install dependencies

# %% [markdown]
# Mount your google drive (might take few seconds for dialog to appear).

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/Shareddrives
import os
folder = os.path.join(os.popen('pwd | tr -d \'\n\'').read(),os.popen('ls | grep QPCC_1_ | tr -d \'\n\'').read())
os.chdir(folder)
os.getcwd()
# %cd QPCC
# Out:
# Mounted at /content/drive
# /content/drive/Shareddrives
# '/content/drive/Shareddrives/QPCC_1_Daniel_Lete'

# %% [markdown]
# Install the required python packages.

# %%
# !pip install --quiet -r 'Material/requirements.txt'
from qpcc import *
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.4/993.4 KB 13.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 53.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 76.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.5/241.5 KB 19.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 KB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 65.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.5/37.5 MB 15.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 4.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Lecture

# %% [markdown]
# The lecture video is accessible directly in the notebook below or in Youtube - link to full video and chapter available below.

# %%
lecture = 'Lec004'
qpcc_player(video_id=lecture)

# %% [markdown]
# ### Direct Youtube link
#
# [Full lecture](https://www.youtube.com/watch?v=CcVlVLLh8M0&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd)
#
#
# ### Chapters
#
# [00:15](https://www.youtube.com/watch?v=CcVlVLLh8M0&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd&index=7&t=15s) Introduction
#
# [01:16](https://www.youtube.com/watch?v=CcVlVLLh8M0&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd&index=7&t=76s) Quantum Computing Fundamentals
#
# [08:38](https://www.youtube.com/watch?v=CcVlVLLh8M0&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd&index=7&t=518s) Building Quantum Computers
#
# [14:39](https://www.youtube.com/watch?v=CcVlVLLh8M0&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd&index=7&t=879s) Challenges in building Quantum Computers
#
# [15:59](https://www.youtube.com/watch?v=CcVlVLLh8M0&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd&index=7&t=959s) Tackling Quantum Noise
#
# [19:29](https://www.youtube.com/watch?v=CcVlVLLh8M0&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd&index=7&t=1169s) Quantum Industry Roadmap

# %% [markdown]
# # Tutorial
# ##### For each question in the quiz, select all choices that you think are correct

# %%
qpcc_quiz(lecture)
# Out:
# <div id="GLwUxqlhmHyI" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-numquestions="1000000"> <style>:root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Answer {
#     margin: 10px 0;
#     display: grid;
#     grid-template-columns: auto auto;
#     grid-gap: 10px;
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
# ...

# %% [markdown]
# There are a number of cards below that could be used to check your undertstanding ot the topics presented in the lecture and they could also be used as discission points in the tutorial. Clicking on a card would reveal an answer.

# %%
qpcc_cards(lecture)

# %% [markdown]
# # Exercises

# %% [markdown]
# In this Module we will use the IBM Quantum Composer online to experimentally demonstrate some of the concepts we covered in the lecture
#
# 1. Prepare a circuit one of the Bell states and measure the qubits on a real hardware and compare the results obtained in comparison to the Classical Ideal simulator
#
# 2. Perform the experiments on different IBM hardware backends with different Quantum Volumes and compare the results.
#
# 3. **3 Qubit Entanglement** - In the previous module we built a 2 qubit entangled state namely the bell state in this Module we'll build the 3-qubit maximally entangled state called the [GHZ state](https://quantum-computing.ibm.com/composer/docs/iqx/guide/entanglement#ghz-states) using the circuit below and observe the correlation of measurements similar to the Bell state
#
# ![ghz-circ3.png](data:image/png;base64,...)
#
# 4. Optional Advanced Question : Emulating Noisy gates on IBM Composer, Performing 4 (pi/2) rotations around the X axis on a qubit initialized in the state |0⟩ should bring it back to the state |0⟩
#     1. Prepare a circuit that performs these rotations and look at the effect  on the Statevector and the Q-Sphere after each (pi/2) rotation
#     2. We now want to see what is the effect of a small incremental error in each of the gates, instead of implementing exactly a (pi/2) rotation what if each gate has and error of 0.05*pi, how does this error propogate for each addition of the gate, how far is the final state in comparison to the ideal gate situation.

# %% [markdown]
# # References

# %% [markdown]
# The following references are optional reading material:
# 1.  Review of Qubit technologies and their features [link](https://quantumtech.blog/2022/10/20/quantum-computing-modalities-a-qubit-primer-revisited/)
# 2. More information about Noise and it's effects for both [Coherent Noise](https://learn.qiskit.org/summer-school/2021/lec3-1-noise-quantum-computers-1) and [Incoherent Noise](https://learn.qiskit.org/summer-school/2021/lec3-2-noise-quantum-computers-pt-2)
# 3. Example Error mitigation scheme [ZNE-Zero Noise Extrapolation](https://mitiq.readthedocs.io/en/stable/guide/zne.html)
# 4. Introduction to Classical and Quantum Computing([pdf](https://www.thomaswong.net/introduction-to-classical-and-quantum-computing-1e3p.pdf))
#
#   Chapters :
#
#   5.1.3, 5.1.4 - Quantum Processor and Simulator on Qiskit Composer
#
#   1.6 - Classical Error Correction schemes
#
#   2.5 - Physical Qubits
#
#   4.7.1 - Quantum Error Correction and Decoherence
#
# 5. Optional references for Advanced Question
#   1. Introduction to [Bloch Sphere](https://qiskit.org/textbook/ch-states/representing-qubit-states.html#3.-The-Bloch-Sphere-) and [Q-Sphere](https://quantum-computing.ibm.com/admin/docs/iqx/visualizations#q-sphere-view).
#
#   2. Short videos introducing [Bloch Sphere](https://www.youtube.com/watch?v=Pfk_9RNQA5A), [rotation gates](https://www.youtube.com/watch?v=nejFfcXumjM)
