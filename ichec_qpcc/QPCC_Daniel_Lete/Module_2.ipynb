# %% [markdown]
# ## Mount google drive and install dependencies

# %% [markdown]
# Mount your google drive (might take few seconds for dialog to appear).

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/Shareddrives
import os
folder = os.path.join(os.popen('pwd | tr -d \'\n\'').read(),os.popen('ls | grep QPCC_1_ | tr -d \'\n\'').read())
os.chdir(folder)
os.getcwd()
# %cd QPCC
# Out:
# Mounted at /content/drive
# /content/drive/Shareddrives
# '/content/drive/Shareddrives/QPCC_1_Daniel_Lete'

# %% [markdown]
# Install the required python packages.

# %%
# !pip install --quiet -r 'Material/requirements.txt'
from qpcc import *
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.4/993.4 KB 42.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 78.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 83.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.3/241.3 KB 24.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 KB 12.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.5/37.5 MB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 62.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 5.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Module 2: Integrating Classical & Quantum Computing

# %% [markdown]
# # Lecture

# %% [markdown]
# The lecture video is accessible directly in the notebook below or in Youtube - link to full video and chapter available below.

# %%
lecture = 'Lec002'
qpcc_player(video_id=lecture)

# %% [markdown]
# ### Direct Youtube link
#
# [Full lecture](https://www.youtube.com/watch?v=WQme0EqcQ-k&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd)
#
#
# ### Chapters
#
# [00:00:00](https://www.youtube.com/watch?v=WQme0EqcQ-k&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd&index=2&t=0s) - Outline
#
# [00:01:38](https://www.youtube.com/watch?v=WQme0EqcQ-k&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd&index=2&t=98s) - Why integrate classical & quantum computing?
#
# [00:39:37](https://www.youtube.com/watch?v=WQme0EqcQ-k&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd&index=2&t=2377s) - How to integrate classical & quantum computing?
#
# [01:00:42](https://www.youtube.com/watch?v=WQme0EqcQ-k&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd&index=2&t=3642s) - Who is integrateing classical & quantum computing?
#
# [01:13:05](https://www.youtube.com/watch?v=WQme0EqcQ-k&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd&index=2&t=4385s) - Road ahead for integrating classical & quantum computing?
#
# [01:20:12](https://www.youtube.com/watch?v=WQme0EqcQ-k&list=PLMEnuZvWVaIsqCBnroopxXEng2Z-jcWnd&index=2&t=4812s) - Wrap-up

# %% [markdown]
# # Tutorial
# ##### For each question in the quiz, select all choices that you think are correct

# %%
qpcc_quiz(lecture)

# %% [markdown]
# There are a number of cards below that could be used to check your undertstanding ot the topics presented in the lecture and they could also be used as discission points in the tutorial. Clicking on a card would reveal an answer.

# %%
qpcc_cards(lecture)

# %% [markdown]
# # Exercises

# %% [markdown]
# The exercise for this lecture will be to extend the *QPCC Self-Study Report* which you had created in *Module 1*.
#
# To the report, add your understanding and objectives related to the following 4 (four) items from this lecture:
#
#  1. Describe your understanding of why classical HPC and quantum computing are related to and relevant for each other.
#  2. Modify or update the HPC problem/use-case that you had identified in *Module 1* and add suggestive high-level ideas of where there may be potential to explore a hybrid HPC-QC approach.​ You may choose to investigate this further with the cohort, ICHEC staff or external parties/material.
#  3. List which hybrid HPC-QC platforms/stakeholders among those that are being developed (enterprises, national/European projects, etc.) would you like to engage, gather more information, or gain access. Outline your motivation and targeted outcomes for this.
#  4. Based on your learnings from *Module 1* and *Module 2*, summarise your next steps in your learning path and engaging with the HPC and QC communities. If suitable, outline short-term (6-12 months) and/or medium-term (12-24 months) roadmaps and objectives for your or your organisation's capability building in hybrid high-performance quantum computing through training, projects, collaborations, etc..
#
# For Business Leaders, this version of your report will serve to summarise your learning outcomes and as a roadmap ahead.
#
# For Technical Managers, this version of your report will be further refined in the subsequent lecture exercises by incrementally adding more details and ideas.

# %% [markdown]
# # References

# %% [markdown]
# The following references are optional reading material:
# 1.   EuroQCS Joint White Paper ([pdf](https://qt.eu//app/uploads/2022/02/20220202_HPC-QCS-JWP-final.pdf)). https://qt.eu/about-quantum-flagship/newsroom/european-quantum-computing-simulation/
# 2.   High-Performance Computer Quantum Simulator hybrid (HPCQS), https://hpcqs.eu/
# 3. Bringing quantum acceleration to supercomputers ([pdf](https://meetiqm.com/uploads/documents/IQM_HPC-QC-Integration-Whitepaper.pdf)). https://www.hpcqc.org/
