# %%
try:
    import cirq
except ImportError:
    print("installing cirq...")
    # !pip install --quiet cirq
    print("installed cirq.")
    import cirq

import cirq_google
# Out:
# installing cirq...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 15.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 692.6 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.6/594.6 kB 11.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.4/577.4 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 11.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.2/120.2 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.4/223.4 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 1.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# # First Bell State
#
# # 1/sqrt(2) * ( |00⟩ + |11⟩ )

# %%
# Create a circuit to generate a Bell State:
# 1/sqrt(2) * ( |00⟩ + |11⟩ )
bell_circuit1 = cirq.Circuit()
q0, q1 = cirq.LineQubit.range(2)
bell_circuit1.append(cirq.H(q0))
bell_circuit1.append(cirq.CNOT(q0, q1))

# Initialize Simulator
s = cirq.Simulator()

print('Simulate the circuit:')
results = s.simulate(bell_circuit1)
print(results)

# For sampling, we need to add a measurement at the end
bell_circuit1.append(cirq.measure(q0, q1, key='result'))



# Sample the circuit
samples = s.run(bell_circuit1, repetitions=1000)
# Out:
# Simulate the circuit:
# measurements: (no measurements)
#
# qubits: (cirq.LineQubit(0), cirq.LineQubit(1))
# output vector: 0.707|00⟩ + 0.707|11⟩
#
# phase:
# output vector: |⟩

# %%
print(bell_circuit1)
# Out:
# 0: ───H───@───M('result')───
#           │   │
# 1: ───────X───M─────────────

# %%
# Visualizing the measurement results using a graphical plot

import matplotlib.pyplot as plt

cirq.plot_state_histogram(samples, plt.subplot())
plt.show()

# %% [markdown]
# # Second Bell State
#
# # 1/sqrt(2) * ( |01⟩ + |10⟩ )

# %%
# Create a circuit to generate the second Bell State:
# 1/sqrt(2) * ( |01⟩ + |10⟩ )
bell_circuit2 = cirq.Circuit()
q0, q1 = cirq.LineQubit.range(2)
bell_circuit2.append(cirq.H(q0))
bell_circuit2.append(cirq.X(q1)) # Additional X gate added to bottom qubit
bell_circuit2.append(cirq.CNOT(q0, q1))

# Initialize Simulator
s = cirq.Simulator()

print('Simulate the circuit:')
results = s.simulate(bell_circuit2)
print(results)

# For sampling, we need to add a measurement at the end
bell_circuit2.append(cirq.measure(q0, q1, key='result'))



# Sample the circuit
samples = s.run(bell_circuit2, repetitions=1000)
# Out:
# Simulate the circuit:
# measurements: (no measurements)
#
# qubits: (cirq.LineQubit(0), cirq.LineQubit(1))
# output vector: 0.707|01⟩ + 0.707|10⟩
#
# phase:
# output vector: |⟩

# %%
print(bell_circuit2)
# Out:
# 0: ───H───@───M('result')───
#           │   │
# 1: ───X───X───M─────────────

# %%
# Visualizing the measurement results using a graphical plot

import matplotlib.pyplot as plt

cirq.plot_state_histogram(samples, plt.subplot())
plt.show()

# %% [markdown]
# # Third Bell State
#
# # 1/sqrt(2) * ( |00⟩ - |11⟩ )

# %%
# Create a circuit to generate the 3rd Bell State:
# 1/sqrt(2) * ( |00⟩ - |11⟩ )
bell_circuit3 = cirq.Circuit()
q0, q1 = cirq.LineQubit.range(2)
bell_circuit3.append(cirq.X(q0)) #Additional X gate added to first qubit
bell_circuit3.append(cirq.H(q0))
bell_circuit3.append(cirq.CNOT(q0, q1))

# Initialize Simulator
s = cirq.Simulator()

print('Simulate the circuit:')
results = s.simulate(bell_circuit3)
print(results)

# For sampling, we need to add a measurement at the end
bell_circuit3.append(cirq.measure(q0, q1, key='result'))



# Sample the circuit
samples = s.run(bell_circuit3, repetitions=1000)
# Out:
# Simulate the circuit:
# measurements: (no measurements)
#
# qubits: (cirq.LineQubit(0), cirq.LineQubit(1))
# output vector: 0.707|00⟩ - 0.707|11⟩
#
# phase:
# output vector: |⟩

# %%
print(bell_circuit3)
# Out:
# 0: ───X───H───@───M('result')───
#               │   │
# 1: ───────────X───M─────────────

# %%
# Visualizing the measurement results using a graphical plot

import matplotlib.pyplot as plt

cirq.plot_state_histogram(samples, plt.subplot())
plt.show()

# %% [markdown]
# # Fourth Bell State
#
# # 1/sqrt(2) * ( |01⟩ - |10⟩ )

# %%
# Create a circuit to generate a Bell State:
# 1/sqrt(2) * ( |01⟩ - |10⟩ )
bell_circuit4 = cirq.Circuit()
q0, q1 = cirq.LineQubit.range(2)
bell_circuit4.append(cirq.X(q0)) #Addtional X gates added to both first and second qubits
bell_circuit4.append(cirq.X(q1))
bell_circuit4.append(cirq.H(q0))
bell_circuit4.append(cirq.CNOT(q0, q1))

# Initialize Simulator
s = cirq.Simulator()

print('Simulate the circuit:')
results = s.simulate(bell_circuit4)
print(results)

# For sampling, we need to add a measurement at the end
bell_circuit4.append(cirq.measure(q0, q1, key='result'))



# Sample the circuit
samples = s.run(bell_circuit4, repetitions=1000)
# Out:
# Simulate the circuit:
# measurements: (no measurements)
#
# qubits: (cirq.LineQubit(0), cirq.LineQubit(1))
# output vector: 0.707|01⟩ - 0.707|10⟩
#
# phase:
# output vector: |⟩

# %%
print(bell_circuit4)
# Out:
# 0: ───X───H───@───M('result')───
#               │   │
# 1: ───X───────X───M─────────────

# %%
# Visualizing the measurement results using a graphical plot

import matplotlib.pyplot as plt

cirq.plot_state_histogram(samples, plt.subplot())
plt.show()
