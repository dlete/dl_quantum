# %% [markdown]
# # Module 6: Software and Tools for Quantum Programming

# %% [markdown]
# ## Mount google drive and install dependencies

# %% [markdown]
# Mount your google drive (might take few seconds for dialog to appear).

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/Shareddrives
import os
#folder = os.path.join(os.popen('pwd | tr -d \'\n\'').read(),os.popen('ls | grep QPCC_1_ | tr -d \'\n\'').read())
#os.chdir(folder)
#os.getcwd()
# %cd QPCC
# Out:
# Mounted at /content/drive
# /content/drive/Shareddrives
# /content/drive/Shareddrives/QPCC

# %% [markdown]
# Install the required python packages.

# %%
# !pip install --quiet -r 'Material/requirements.txt'
from qpcc import *

# %% [markdown]
# # Lecture

# %% [markdown]
# The lecture video is accessible directly in the notebook below or in Youtube - link to full video and chapter available below.

# %%
lecture = 'Lec006'
qpcc_player(video_id=lecture)

# %% [markdown]
# ### Direct Youtube link
#
# [Full lecture](https://www.youtube.com/watch?v=Lb2o6Qb8zxY)
#
#
# ### Chapters
# [00:00](https://www.youtube.com/watch?v=Lb2o6Qb8zxY&t=0s) Intro
#
# [02:43](https://www.youtube.com/watch?v=Lb2o6Qb8zxY&t=163s) High Level Quantum Software
#
# [10:29](https://www.youtube.com/watch?v=Lb2o6Qb8zxY&t=629s) Low Level Quantum Software
#
# [11:56](https://www.youtube.com/watch?v=Lb2o6Qb8zxY&t=716s) Quantum Programming as a Service
#
# [14:13](https://www.youtube.com/watch?v=Lb2o6Qb8zxY&t=853s) Quantum Workflow & Orchestrators
#
# [15:20](https://www.youtube.com/watch?v=Lb2o6Qb8zxY&t=920s) Custom Quantum Software Stacks

# %% [markdown]
# # Tutorial
# ##### For each question in the quiz, select all choices that you think are correct

# %%
qpcc_quiz(lecture)
# Out:
# <div id="NjhiGwgkNXTC" data-shufflequestions="False"
#                data-shuffleanswers="True"
#                data-numquestions="1000000"> <style>:root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-bottom: 15px;
#     padding-bottom: 4px;
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Answer {
#     margin: 10px 0;
#     display: grid;
#     grid-template-columns: auto auto;
#     grid-gap: 10px;
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
# ...

# %% [markdown]
# There are a number of cards below that could be used to check your undertstanding ot the topics presented in the lecture and they could also be used as discission points in the tutorial. Clicking on a card would reveal an answer.

# %%
qpcc_cards(lecture)
# Out:
# <style>
# :root{
#   --asparagus: #87a878ff;
#   --terra-cotta: #e26d5aff;
#   --cyan-process: #5bc0ebff;
#   --dark-blue-gray: #666a86ff;
#   --snow: #fffafbff;
#   --rich-black-fogra-39: #090c08ff;
# }
#
#
# /* entire container, keeps perspective */
# .flip-container {
# 	perspective: 1000px;
#   touch-action: pinch-zoom pan-y;
# }
#
#
# .flip-container.flip .flipper {
# 	transform: rotateY(180deg);
# 	/*transform: rotateY(180deg)  translateX(-10%); */
# }
#
#
# .flip-container.slide .flipper.frontcard {
#     filter: brightness(90%);
#     position:absolute;
#     z-index: -20;
# }
#
# .flip-container.prepare .flipper.backcard {
#     opacity:1;
#     transition: display 0s;
#     transform:  translateX(20px);
# }
#
#
# .flip-container.slide .flipper.backcard {
#     filter: brightness(115%);
#     height: 360px;
#     opacity:1;
# 	  transform:  rotateY(3deg)  translateX(700px) translateZ(20px) scale(1, 1.05) rotate(3deg);
#     z-index: 20;
# }
#
#
#
#
# ...

# %% [markdown]
# # Exercises

# %% [markdown]
# 1. Extend your report to include a comparison of:
#   - High-level vs low level quantum software
#   - Quantum programming stacks as a service vs custom quantum software stacks
#
# 2. In this module we will use a number of different quantum programming languages to code the Bell states. The Jupyter notebooks for the exercises can be found in the folder _Module_6_Demos_ in your drive (the _Qiskit_Demo.ipynb_  Jupyter notebook contains the same code as the exercise in Module 5 and is included only as a reference).
#
#   2.1 Code the circuits for the Bell states in one of the following quantum programming languages - Pennylane, Cirq or myQLM. Draw the circuits and run the circuits in quantum software simulators. The relevant Jupyter notebooks can be ran directly in Google Colab:
#   - Pennylane_Demo.ipynb
#   - MyQLM_Demo.ipynb
#   - Cirq_Demo.ipynb
#
#   2.2 Optional Advanced exercise : Same as previous exercise, but using either Q# or Julia Yao. Those two quantum programming languages examples need to be run in local Jupyter instance
#     1. Follow the instructions (in the _Module_6_Demos_ folder) to install a local Jupyter instance and the relevant kernels:
#       - Q#_instructions.pdf
#       - Julia_instructions.pdf
#     2. Code the circuits for the Bell states, draw the circuits and run the circuits in quantum software simulators. The relevant Jupyter notebooks that need to be donwloaded be ran in your local Jupyter instance are:
#       - Q#_Demo.ipynb
#       - Yao_Demo.ipynb

# %% [markdown]
# # References

# %% [markdown]
# The following references are optional reading material:
# 1. Pennylane
#   - Main page: [link](https://pennylane.ai/qml/)
#   - Single and Multi Qubit gates and creating a device for simulation: [link](https://pennylane.ai/qml/demos/tutorial_qubit_rotation.html)
#   - Simulators: [link](https://docs.pennylane.ai/en/stable/code/api/pennylane.device.html)
#   - Tutorials: [link](https://pennylane.ai/qml/demonstrations.html)
# 2. Cirq
#   - Main page: [link](https://quantumai.google/cirq)
#   - Single and Multi Qubit gates and operations: [link](https://quantumai.google/cirq/build/gates)
#   - Simulators: [link](https://quantumai.google/cirq/simulate)
#   - Tutorials: [link](https://quantumai.google/cirq/start/basics)
# 3. myQLM
#   - Main page: [link](https://atos.net/en/lp/myqlm)
#   - Writing quantum circuits with single and multi qubit gates: [link](https://myqlm.github.io/programming.html)
#   - Simulators: [link](https://myqlm.github.io/source_doc.html#qpus)
#   - Tutorials: [link](https://myqlm.github.io/notebooks.html), [link](https://myqlm.github.io/simulating.html)
# 4. Q#
#   - Main page: [link](https://learn.microsoft.com/en-us/azure/quantum/)
#   - Single vs Miltiple Qubit gates: [link](https://learn.microsoft.com/en-us/azure/quantum/concepts-multiple-qubits)
#   - Simulators: [link](https://learn.microsoft.com/en-us/azure/quantum/machines/)
#   - Tutorials: [link](https://learn.microsoft.com/en-us/samples/browse/?languages=qsharp)
# 5. Julia Yao
#   - Main page: [link](https://yaoquantum.org/)
#   - Single and Multi Qubit gates: [link](https://yaoquantum.org/tutorials/getting-started/3-yao_code/)
#   - Running a Circuit: [link](https://yaoquantum.org/tutorials/getting-started/4-applications/)
#   - Tutorials: [link](https://yaoquantum.org/tutorials/)
# 6. Qiskit
#   - Main page: [link](https://qiskit.org/documentation/)
#   - Single Qubit gates: [link](https://qiskit.org/textbook/ch-states/single-qubit-gates.html)
#   - Multi Qubit gates: [link](https://qiskit.org/textbook/ch-gates/multiple-qubits-entangled-states.html)
#   - Simulators: [link](https://qiskit.org/documentation/tutorials/simulators/1_aer_provider.html)
#   - Tutorials: [link](https://qiskit.org/documentation/tutorials.html)
